# %% [markdown]
# # Accidental Drug Related Deaths
#
# This is an analysis of Accidental Drug Related Deaths in the US between the years 2012-2018
#
# __Data set from:__ https://catalog.data.gov/dataset/accidental-drug-related-deaths-january-2012-sept-2015
#
# The analysis explores the following questions:
#
# ### *Primary Question:*
# 1. What is the most significant factor determining accidental drug-related death?
#
# ### *Secondary Questions:*
# 1. Which drug or combinations of drugs were most lethal?
# 2. How significant is ‘Age’ as an explanatory variable?
# 3. How significant is ‘Race’ as an explanatory variable?
# 4. Place of death (Residence vs. Other) significant?
# 5. Optional variable we could analyze: Description of Injury (Drug Use, Ingestion, Injection, etc)

# %%
#Imports - Numpy, Pandas, MatPlotLib, Seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

#Show plots magic function
# %matplotlib inline

# %% [markdown]
# ## EDA

# %%
#Get the file and assign it to add_df (stands for Accidental Drug Deaths DataFrame)
#add_df = pd.read_csv('../data/raw/Accidental_Drug_Related_Deaths_2012-2018.csv')
DrugData = pd.read_csv('../data/raw/Accidental_Drug_Related_Deaths_2012-2018.csv')
Holiday_Data=pd.read_csv('../data/raw/US Holidays 2012-2018.csv',sep=',')
locales=pd.read_csv('../data/raw/locales.csv')
connecticut=pd.read_csv('../data/raw/connecticut_pop.csv')

#Check the info and data
DrugData.info()
DrugData.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5105 entries, 0 to 5104
# Data columns (total 41 columns):
# ID                     5105 non-null object
# Date                   5103 non-null object
# DateType               5103 non-null object
# Age                    5102 non-null float64
# Sex                    5099 non-null object
# Race                   5092 non-null object
# ResidenceCity          4932 non-null object
# ResidenceCounty        4308 non-null object
# ResidenceState         3556 non-null object
# DeathCity              5100 non-null object
# DeathCounty            4005 non-null object
# Location               5081 non-null object
# LocationifOther        590 non-null object
# DescriptionofInjury    4325 non-null object
# InjuryPlace            5039 non-null object
# InjuryCity             3349 non-null object
# InjuryCounty           2364 non-null object
# InjuryState            1424 non-null object
# COD                    5105 non-null object
# OtherSignifican        169 non-null object
# Heroin                 2529 non-null object
# Cocaine                1521 non-null object
# Fentanyl               2232 non-null object
# FentanylAnalogue       389 non-null object
# Oxycodone              607 non-null object
# Oxymorphone            108 non-null object
# Ethanol                1247 non-null object
# Hydrocodone            118 non-null object
# Benzodiazepine         1343 non-null object
# Methadone              474 non-null object
# Amphet                 159 non-null object
# Tramad                 130 non-null object
# Morphine_NotHeroin     42 non-null object
# Hydromorphone          25 non-null object
# Other                  435 non-null object
# OpiateNOS              88 non-null object
# AnyOpioid              2466 non-null object
# MannerofDeath          5095 non-null object
# DeathCityGeo           5105 non-null object
# InjuryCityGeo          3329 non-null object
# ResidenceCityGeo       4932 non-null object
# dtypes: float64(1), object(40)
# memory usage: 1.6+ MB
#         ID                    Date     DateType   Age   Sex   Race  \
# 0  12-0001  01/01/2012 12:00:00 AM  DateofDeath  35.0  Male  White
# 1  12-0002  01/03/2012 12:00:00 AM  DateofDeath  41.0  Male  White
# 2  12-0003  01/04/2012 12:00:00 AM  DateofDeath  61.0  Male  Black
# 3  12-0004  01/05/2012 12:00:00 AM  DateofDeath  51.0  Male  White
# 4  12-0005  01/07/2012 12:00:00 AM  DateofDeath  45.0  Male  White
#
#   ResidenceCity ResidenceCounty ResidenceState   DeathCity  \
# 0        HEBRON         TOLLAND            NaN      HEBRON
# 1       BRISTOL        HARTFORD            NaN     BRISTOL
# 2       DANBURY       FAIRFIELD            NaN     DANBURY
# 3     STRATFORD       FAIRFIELD            NaN  BRIDGEPORT
# 4      HARTFORD        HARTFORD            NaN    HARTFORD
#
#                    ...                  Tramad Morphine_NotHeroin  \
# 0                  ...                     NaN                NaN
# 1                  ...                     NaN                NaN
# 2                  ...                     NaN                NaN
# 3                  ...                     NaN                NaN
# 4                  ...                     NaN                NaN
#
#   Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 0           NaN   NaN       NaN       NaN      Accident
# 1           NaN   NaN       NaN       NaN      Accident
# 2           NaN   NaN       NaN       NaN      Accident
# 3           NaN   NaN       NaN       NaN      Accident
# 4           NaN   NaN       NaN       NaN      Accident
#
#                                 DeathCityGeo InjuryCityGeo  \
# 0      HEBRON, CT\r\n(41.658069, -72.366324)           NaN
# 1     Bristol, CT\r\n(41.673037, -72.945791)           NaN
# 2     Danbury, CT\r\n(41.393666, -73.451539)           NaN
# 3  BRIDGEPORT, CT\r\n(41.179195, -73.189476)           NaN
# 4    HARTFORD, CT\r\n(41.765775, -72.673356)           NaN
#
#                        ResidenceCityGeo
# 0     HEBRON\r\n(43.694742, -71.808963)
# 1    BRISTOL\r\n(41.673037, -72.945791)
# 2    DANBURY\r\n(41.393666, -73.451539)
# 3  STRATFORD\r\n(41.200888, -73.131323)
# 4   HARTFORD\r\n(41.765775, -72.673356)
#
# [5 rows x 41 columns]

# %%
#Check missing data
DrugData.isnull().sum()
# Out:
# ID                        0
# Date                      2
# DateType                  2
# Age                       3
# Sex                       6
# Race                     13
# ResidenceCity           173
# ResidenceCounty         797
# ResidenceState         1549
# DeathCity                 5
# DeathCounty            1100
# Location                 24
# LocationifOther        4515
# DescriptionofInjury     780
# InjuryPlace              66
# InjuryCity             1756
# InjuryCounty           2741
# InjuryState            3681
# COD                       0
# OtherSignifican        4936
# Heroin                 2576
# Cocaine                3584
# Fentanyl               2873
# FentanylAnalogue       4716
# Oxycodone              4498
# Oxymorphone            4997
# Ethanol                3858
# Hydrocodone            4987
# Benzodiazepine         3762
# Methadone              4631
# Amphet                 4946
# Tramad                 4975
# Morphine_NotHeroin     5063
# Hydromorphone          5080
# Other                  4670
# OpiateNOS              5017
# AnyOpioid              2639
# MannerofDeath            10
# DeathCityGeo              0
# InjuryCityGeo          1776
# ResidenceCityGeo        173
# dtype: int64

# %%
#Dropping rows with irreplaceable null values
DrugData.dropna(subset=['Date', 'Age', 'Sex', 'Race'], inplace=True)
DrugData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5088 entries, 0 to 5104
# Data columns (total 41 columns):
# ID                     5088 non-null object
# Date                   5088 non-null object
# DateType               5088 non-null object
# Age                    5088 non-null float64
# Sex                    5088 non-null object
# Race                   5088 non-null object
# ResidenceCity          4921 non-null object
# ResidenceCounty        4299 non-null object
# ResidenceState         3547 non-null object
# DeathCity              5087 non-null object
# DeathCounty            3997 non-null object
# Location               5068 non-null object
# LocationifOther        588 non-null object
# DescriptionofInjury    4311 non-null object
# InjuryPlace            5023 non-null object
# InjuryCity             3336 non-null object
# InjuryCounty           2355 non-null object
# InjuryState            1419 non-null object
# COD                    5088 non-null object
# OtherSignifican        168 non-null object
# Heroin                 2525 non-null object
# Cocaine                1514 non-null object
# Fentanyl               2225 non-null object
# FentanylAnalogue       388 non-null object
# Oxycodone              605 non-null object
# Oxymorphone            107 non-null object
# Ethanol                1242 non-null object
# Hydrocodone            116 non-null object
# Benzodiazepine         1338 non-null object
# Methadone              472 non-null object
# Amphet                 159 non-null object
# Tramad                 130 non-null object
# Morphine_NotHeroin     42 non-null object
# Hydromorphone          25 non-null object
# Other                  432 non-null object
# OpiateNOS              88 non-null object
# AnyOpioid              2458 non-null object
# MannerofDeath          5080 non-null object
# DeathCityGeo           5088 non-null object
# InjuryCityGeo          3316 non-null object
# ResidenceCityGeo       4921 non-null object
# dtypes: float64(1), object(40)
# memory usage: 1.6+ MB

# %%
#Deal with date, adding column year, month, day_of_week, Holiday
date_new = pd.to_datetime(DrugData['Date'])
DrugData.insert(loc=2, column='new_date', value=date_new)
DrugData.insert(loc=3,column='Year',value=DrugData['new_date'].dt.year)

DrugData.insert(loc=4,column='Month',value=DrugData['new_date'].dt.month)
months={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
DrugData['Month'] = DrugData['Month'].apply(lambda x: months[x])

DrugData.insert(loc=5,column='day_of_week',value=DrugData['new_date'].dt.dayofweek)
days = {0:'Mon',1:'Tue',2:'Wed',3:'Thur',4:'Fri',5:'Sat',6:'Sun'}
DrugData['day_of_week'] = DrugData['day_of_week'].apply(lambda x: days[x])

# %%
#merge holiday dates with DrugDates
Holiday_Data['Date']=pd.to_datetime(Holiday_Data['Date'])
Holiday_Data.rename(columns={'Date':'new_date'},inplace=True)
Drug_Data = pd.merge(DrugData, Holiday_Data, on='new_date', how='left')
Holiday_col=Drug_Data.pop('Holiday')
Drug_Data.insert(loc=6,column='Holiday',value=Holiday_col)
Drug_Data.head()
# Out:
#         ID                    Date   new_date  Year Month day_of_week Holiday  \
# 0  12-0001  01/01/2012 12:00:00 AM 2012-01-01  2012   Jan         Sun     NaN
# 1  12-0002  01/03/2012 12:00:00 AM 2012-01-03  2012   Jan         Tue     NaN
# 2  12-0003  01/04/2012 12:00:00 AM 2012-01-04  2012   Jan         Wed     NaN
# 3  12-0004  01/05/2012 12:00:00 AM 2012-01-05  2012   Jan        Thur     NaN
# 4  12-0005  01/07/2012 12:00:00 AM 2012-01-07  2012   Jan         Sat     NaN
#
#       DateType   Age   Sex                  ...                  Tramad  \
# 0  DateofDeath  35.0  Male                  ...                     NaN
# 1  DateofDeath  41.0  Male                  ...                     NaN
# 2  DateofDeath  61.0  Male                  ...                     NaN
# 3  DateofDeath  51.0  Male                  ...                     NaN
# 4  DateofDeath  45.0  Male                  ...                     NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 0                NaN           NaN   NaN       NaN       NaN      Accident
# 1                NaN           NaN   NaN       NaN       NaN      Accident
# 2                NaN           NaN   NaN       NaN       NaN      Accident
# 3                NaN           NaN   NaN       NaN       NaN      Accident
# 4                NaN           NaN   NaN       NaN       NaN      Accident
#
#                                 DeathCityGeo InjuryCityGeo  \
# 0      HEBRON, CT\r\n(41.658069, -72.366324)           NaN
# 1     Bristol, CT\r\n(41.673037, -72.945791)           NaN
# 2     Danbury, CT\r\n(41.393666, -73.451539)           NaN
# 3  BRIDGEPORT, CT\r\n(41.179195, -73.189476)           NaN
# 4    HARTFORD, CT\r\n(41.765775, -72.673356)           NaN
#
#                        ResidenceCityGeo
# 0     HEBRON\r\n(43.694742, -71.808963)
# 1    BRISTOL\r\n(41.673037, -72.945791)
# 2    DANBURY\r\n(41.393666, -73.451539)
# 3  STRATFORD\r\n(41.200888, -73.131323)
# 4   HARTFORD\r\n(41.765775, -72.673356)
#
# [5 rows x 46 columns]

# %%
#Adding back missing value in Residence State: the result could adding back Residence state 1308 missing value
# extract ResidenceCity,ResidenceState create reference table Residency_Adj
Residency_Adj=Drug_Data.loc[:, ['ResidenceCity','ResidenceState']]
Residency_Adj= Residency_Adj.groupby(['ResidenceCity', 'ResidenceState']).size().reset_index(name='Freq')
#Residency_Adj.info()
#check whether the column ResidenceCity has duplicate value
Residency_Adj['is_duplicated'] = Residency_Adj.duplicated(['ResidenceCity'],keep=False)
Residency_Adj['is_duplicated'].sum()
Residency_Adj[Residency_Adj['is_duplicated']==True]
#Drop the rows in Residency_Adj , only keep the right State for the duplicate cities.
#from wiki, Brooklyn belongs to state NY, Hampton to state NH, PLYMOUTH belongs to MA, REDDING states should be CA 
#and WARREN state is RI
Residency_Adj=Residency_Adj.drop([30,96,206,217,277,278],axis=0)
Residency_Adj.at[218,'ResidenceState']='CA'

#check whether the column ResidenceCity has duplicate value
Residency_Adj['is_duplicated'] = Residency_Adj.duplicated(['ResidenceCity'],keep=False)
Residency_Adj[Residency_Adj['is_duplicated']==True]
#Residency_Adj.info()

#use the reference table Residency_Adj to generate new column Residence_State_updated in Drug_Data with less missing value
Residency_Adj.rename(columns={'ResidenceState':'ResidenceState_update'},inplace=True)
add_df = pd.merge(Drug_Data, Residency_Adj, on='ResidenceCity', how='left')
Rstate_col=add_df.pop('ResidenceState_update')
add_df.insert(loc=12,column='ResidenceState_update',value=Rstate_col)
add_df=add_df.drop(['Freq','is_duplicated'],axis=1)
add_df.head()
# Out:
#         ID                    Date   new_date  Year Month day_of_week Holiday  \
# 0  12-0001  01/01/2012 12:00:00 AM 2012-01-01  2012   Jan         Sun     NaN
# 1  12-0002  01/03/2012 12:00:00 AM 2012-01-03  2012   Jan         Tue     NaN
# 2  12-0003  01/04/2012 12:00:00 AM 2012-01-04  2012   Jan         Wed     NaN
# 3  12-0004  01/05/2012 12:00:00 AM 2012-01-05  2012   Jan        Thur     NaN
# 4  12-0005  01/07/2012 12:00:00 AM 2012-01-07  2012   Jan         Sat     NaN
#
#       DateType   Age   Sex                  ...                  Tramad  \
# 0  DateofDeath  35.0  Male                  ...                     NaN
# 1  DateofDeath  41.0  Male                  ...                     NaN
# 2  DateofDeath  61.0  Male                  ...                     NaN
# 3  DateofDeath  51.0  Male                  ...                     NaN
# 4  DateofDeath  45.0  Male                  ...                     NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# 0                NaN           NaN   NaN       NaN       NaN      Accident
# 1                NaN           NaN   NaN       NaN       NaN      Accident
# 2                NaN           NaN   NaN       NaN       NaN      Accident
# 3                NaN           NaN   NaN       NaN       NaN      Accident
# 4                NaN           NaN   NaN       NaN       NaN      Accident
#
#                                 DeathCityGeo InjuryCityGeo  \
# 0      HEBRON, CT\r\n(41.658069, -72.366324)           NaN
# 1     Bristol, CT\r\n(41.673037, -72.945791)           NaN
# 2     Danbury, CT\r\n(41.393666, -73.451539)           NaN
# 3  BRIDGEPORT, CT\r\n(41.179195, -73.189476)           NaN
# 4    HARTFORD, CT\r\n(41.765775, -72.673356)           NaN
#
#                        ResidenceCityGeo
# 0     HEBRON\r\n(43.694742, -71.808963)
# 1    BRISTOL\r\n(41.673037, -72.945791)
# 2    DANBURY\r\n(41.393666, -73.451539)
# 3  STRATFORD\r\n(41.200888, -73.131323)
# 4   HARTFORD\r\n(41.765775, -72.673356)
#
# [5 rows x 47 columns]

# %%
add_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5088 entries, 0 to 5087
# Data columns (total 47 columns):
# ID                       5088 non-null object
# Date                     5088 non-null object
# new_date                 5088 non-null datetime64[ns]
# Year                     5088 non-null int64
# Month                    5088 non-null object
# day_of_week              5088 non-null object
# Holiday                  155 non-null object
# DateType                 5088 non-null object
# Age                      5088 non-null float64
# Sex                      5088 non-null object
# Race                     5088 non-null object
# ResidenceCity            4921 non-null object
# ResidenceState_update    4853 non-null object
# ResidenceCounty          4299 non-null object
# ResidenceState           3547 non-null object
# DeathCity                5087 non-null object
# DeathCounty              3997 non-null object
# Location                 5068 non-null object
# LocationifOther          588 non-null object
# DescriptionofInjury      4311 non-null object
# InjuryPlace              5023 non-null object
# InjuryCity               3336 non-null object
# InjuryCounty             2355 non-null object
# InjuryState              1419 non-null object
# COD                      5088 non-null object
# OtherSignifican          168 non-null object
# Heroin                   2525 non-null object
# Cocaine                  1514 non-null object
# Fentanyl                 2225 non-null object
# FentanylAnalogue         388 non-null object
# Oxycodone                605 non-null object
# Oxymorphone              107 non-null object
# Ethanol                  1242 non-null object
# Hydrocodone              116 non-null object
# Benzodiazepine           1338 non-null object
# Methadone                472 non-null object
# Amphet                   159 non-null object
# Tramad                   130 non-null object
# Morphine_NotHeroin       42 non-null object
# Hydromorphone            25 non-null object
# Other                    432 non-null object
# OpiateNOS                88 non-null object
# AnyOpioid                2458 non-null object
# MannerofDeath            5080 non-null object
# DeathCityGeo             5088 non-null object
# InjuryCityGeo            3316 non-null object
# ResidenceCityGeo         4921 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(44)
# memory usage: 1.9+ MB

# %%
#Splitting DeathCityGeo and ResidenceCityGeo into Coordinates(long/lat) and Cities
add_df[['DeathCityCounty', 'DeathCoordinates']] = add_df['DeathCityGeo'].str.split('\n', expand = True)
add_df[['DeathCityExtracted', 'DeathCountyExtracted']] = add_df['DeathCityCounty'].str.split(',', expand = True)
add_df[['ResidenceCityExtracted', 'ResidenceCoordinates']] =add_df['ResidenceCityGeo'].str.split('\n', expand = True)

# %%
#Dropping all the columns we're not involved in the analysis
add_df.drop(['ID', 'DateType', 'MannerofDeath', 'ResidenceCounty', 'ResidenceState', 'DeathCounty', 'InjuryPlace', 
               'InjuryCity', 'InjuryCounty', 'InjuryState', 'OtherSignifican', 'InjuryCityGeo', 'COD', 'DeathCountyExtracted', 
               'DeathCityCounty', 'DeathCityGeo', 'ResidenceCityGeo'], axis=1, inplace = True)
add_df.head()
# Out:
#                      Date   new_date  Year Month day_of_week Holiday   Age  \
# 0  01/01/2012 12:00:00 AM 2012-01-01  2012   Jan         Sun     NaN  35.0
# 1  01/03/2012 12:00:00 AM 2012-01-03  2012   Jan         Tue     NaN  41.0
# 2  01/04/2012 12:00:00 AM 2012-01-04  2012   Jan         Wed     NaN  61.0
# 3  01/05/2012 12:00:00 AM 2012-01-05  2012   Jan        Thur     NaN  51.0
# 4  01/07/2012 12:00:00 AM 2012-01-07  2012   Jan         Sat     NaN  45.0
#
#     Sex   Race ResidenceCity           ...            Tramad  \
# 0  Male  White        HEBRON           ...               NaN
# 1  Male  White       BRISTOL           ...               NaN
# 2  Male  Black       DANBURY           ...               NaN
# 3  Male  White     STRATFORD           ...               NaN
# 4  Male  White      HARTFORD           ...               NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid  \
# 0                NaN           NaN   NaN       NaN       NaN
# 1                NaN           NaN   NaN       NaN       NaN
# 2                NaN           NaN   NaN       NaN       NaN
# 3                NaN           NaN   NaN       NaN       NaN
# 4                NaN           NaN   NaN       NaN       NaN
#
#           DeathCoordinates DeathCityExtracted ResidenceCityExtracted  \
# 0  (41.658069, -72.366324)             HEBRON               HEBRON\r
# 1  (41.673037, -72.945791)            Bristol              BRISTOL\r
# 2  (41.393666, -73.451539)            Danbury              DANBURY\r
# 3  (41.179195, -73.189476)         BRIDGEPORT            STRATFORD\r
# 4  (41.765775, -72.673356)           HARTFORD             HARTFORD\r
#
#       ResidenceCoordinates
# 0  (43.694742, -71.808963)
# 1  (41.673037, -72.945791)
# 2  (41.393666, -73.451539)
# 3  (41.200888, -73.131323)
# 4  (41.765775, -72.673356)
#
# [5 rows x 36 columns]

# %%
#Make all string values uppercase
add_df = add_df.applymap(lambda x: x if type(x) != str  else x.upper())

#Checking to make sure NaN values haven't been affected.
add_df.LocationifOther[0]
# Out:
# nan

# %%
#Locating the NaN value in the DeathCity
DeathCityMissingloc = np.where(add_df['DeathCity'].isna())
DeathCityMissingloc
# Out:
# (array([137], dtype=int64),)

# %%
#Filling the NaN value of the DeathCity and overview of the cleaning process
add_df['DeathCity'].fillna(add_df['DeathCityExtracted'], inplace = True)
add_df.info()
add_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5088 entries, 0 to 5087
# Data columns (total 36 columns):
# Date                      5088 non-null object
# new_date                  5088 non-null datetime64[ns]
# Year                      5088 non-null int64
# Month                     5088 non-null object
# day_of_week               5088 non-null object
# Holiday                   155 non-null object
# Age                       5088 non-null float64
# Sex                       5088 non-null object
# Race                      5088 non-null object
# ResidenceCity             4921 non-null object
# ResidenceState_update     4853 non-null object
# DeathCity                 5088 non-null object
# Location                  5068 non-null object
# LocationifOther           588 non-null object
# DescriptionofInjury       4311 non-null object
# Heroin                    2525 non-null object
# Cocaine                   1514 non-null object
# Fentanyl                  2225 non-null object
# FentanylAnalogue          388 non-null object
# Oxycodone                 605 non-null object
# Oxymorphone               107 non-null object
# Ethanol                   1242 non-null object
# Hydrocodone               116 non-null object
# Benzodiazepine            1338 non-null object
# Methadone                 472 non-null object
# Amphet                    159 non-null object
# Tramad                    130 non-null object
# Morphine_NotHeroin        42 non-null object
# Hydromorphone             25 non-null object
# Other                     432 non-null object
# OpiateNOS                 88 non-null object
# AnyOpioid                 2458 non-null object
# DeathCoordinates          5088 non-null object
# DeathCityExtracted        5088 non-null object
# ResidenceCityExtracted    4921 non-null object
# ResidenceCoordinates      4921 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(33)
# memory usage: 1.6+ MB
#                      Date   new_date  Year Month day_of_week Holiday   Age  \
# 0  01/01/2012 12:00:00 AM 2012-01-01  2012   JAN         SUN     NaN  35.0
# 1  01/03/2012 12:00:00 AM 2012-01-03  2012   JAN         TUE     NaN  41.0
# 2  01/04/2012 12:00:00 AM 2012-01-04  2012   JAN         WED     NaN  61.0
# 3  01/05/2012 12:00:00 AM 2012-01-05  2012   JAN        THUR     NaN  51.0
# 4  01/07/2012 12:00:00 AM 2012-01-07  2012   JAN         SAT     NaN  45.0
# 5  01/08/2012 12:00:00 AM 2012-01-08  2012   JAN         SUN     NaN  51.0
# 6  01/08/2012 12:00:00 AM 2012-01-08  2012   JAN         SUN     NaN  24.0
# 7  01/08/2012 12:00:00 AM 2012-01-08  2012   JAN         SUN     NaN  33.0
# 8  01/11/2012 12:00:00 AM 2012-01-11  2012   JAN         WED     NaN  54.0
# 9  01/12/2012 12:00:00 AM 2012-01-12  2012   JAN        THUR     NaN  46.0
#
#       Sex   Race ResidenceCity           ...            Tramad  \
# 0    MALE  WHITE        HEBRON           ...               NaN
# 1    MALE  WHITE       BRISTOL           ...               NaN
# 2    MALE  BLACK       DANBURY           ...               NaN
# 3    MALE  WHITE     STRATFORD           ...               NaN
# 4    MALE  WHITE      HARTFORD           ...               NaN
# 5    MALE  WHITE     WATERBURY           ...               NaN
# 6  FEMALE  WHITE      STAMFORD           ...               NaN
# 7    MALE  WHITE      BROOKLYN           ...               NaN
# 8    MALE  WHITE    DEEP RIVER           ...               NaN
# 9    MALE  WHITE   SOUTHINGTON           ...               NaN
#
#   Morphine_NotHeroin Hydromorphone      Other OpiateNOS AnyOpioid  \
# 0                NaN           NaN        NaN       NaN       NaN
# 1                NaN           NaN        NaN       NaN       NaN
# 2                NaN           NaN        NaN       NaN       NaN
# 3                NaN           NaN        NaN       NaN       NaN
# 4                NaN           NaN        NaN       NaN       NaN
# 5                NaN           NaN        NaN       NaN       NaN
# 6                NaN           NaN        NaN       NaN       NaN
# 7                NaN           NaN        NaN       NaN       NaN
# 8                NaN           NaN        NaN       NaN       NaN
# 9                NaN           NaN  BATH SALT       NaN       NaN
#
#           DeathCoordinates DeathCityExtracted ResidenceCityExtracted  \
# 0  (41.658069, -72.366324)             HEBRON               HEBRON\r
# 1  (41.673037, -72.945791)            BRISTOL              BRISTOL\r
# 2  (41.393666, -73.451539)            DANBURY              DANBURY\r
# 3  (41.179195, -73.189476)         BRIDGEPORT            STRATFORD\r
# 4  (41.765775, -72.673356)           HARTFORD             HARTFORD\r
# 5  (41.554261, -73.043069)          WATERBURY            WATERBURY\r
# 6  (41.051924, -73.539475)           STAMFORD             STAMFORD\r
# 7  (41.914993, -71.911904)             PUTNAM             BROOKLYN\r
# 8  (41.385619, -72.435658)         DEEP RIVER           DEEP RIVER\r
# 9  (41.600428, -72.878105)        SOUTHINGTON          SOUTHINGTON\r
#
#       ResidenceCoordinates
# 0  (43.694742, -71.808963)
# 1  (41.673037, -72.945791)
# 2  (41.393666, -73.451539)
# 3  (41.200888, -73.131323)
# 4  (41.765775, -72.673356)
# 5  (41.554261, -73.043069)
# 6  (41.051924, -73.539475)
# 7  (40.692529, -73.990996)
# 8  (41.385619, -72.435658)
# 9  (41.600428, -72.878105)
#
# [10 rows x 36 columns]

# %%
add_df = pd.merge(add_df, connecticut, left_on='DeathCity', right_on='Town', how='left')
add_df = add_df.drop(['Town'], axis=1)

# %%
add_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5088 entries, 0 to 5087
# Data columns (total 37 columns):
# Date                      5088 non-null object
# new_date                  5088 non-null datetime64[ns]
# Year                      5088 non-null int64
# Month                     5088 non-null object
# day_of_week               5088 non-null object
# Holiday                   155 non-null object
# Age                       5088 non-null float64
# Sex                       5088 non-null object
# Race                      5088 non-null object
# ResidenceCity             4921 non-null object
# ResidenceState_update     4853 non-null object
# DeathCity                 5088 non-null object
# Location                  5068 non-null object
# LocationifOther           588 non-null object
# DescriptionofInjury       4311 non-null object
# Heroin                    2525 non-null object
# Cocaine                   1514 non-null object
# Fentanyl                  2225 non-null object
# FentanylAnalogue          388 non-null object
# Oxycodone                 605 non-null object
# Oxymorphone               107 non-null object
# Ethanol                   1242 non-null object
# Hydrocodone               116 non-null object
# Benzodiazepine            1338 non-null object
# Methadone                 472 non-null object
# Amphet                    159 non-null object
# Tramad                    130 non-null object
# Morphine_NotHeroin        42 non-null object
# Hydromorphone             25 non-null object
# Other                     432 non-null object
# OpiateNOS                 88 non-null object
# AnyOpioid                 2458 non-null object
# DeathCoordinates          5088 non-null object
# DeathCityExtracted        5088 non-null object
# ResidenceCityExtracted    4921 non-null object
# ResidenceCoordinates      4921 non-null object
# Population                5017 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(33)
# memory usage: 1.5+ MB

# %%
#Merge the results
add_df = pd.merge(add_df, locales, on='LocationifOther', how='left')

#Fill the new location field with the original Location field where there are NAs
add_df.cleaned_location = add_df.cleaned_location.fillna(add_df.Location)

#map the key phrases from the location column to more singular locations
place={'NAN':"OTHER",'COMMERCIAL':"COMMERCIAL",'CONVALESCENT HOME':'SUPERVISED CARE/HOSPITAL','HOSPICE':'SUPERVISED CARE/HOSPITAL','NURSING HOME':'SUPERVISED CARE/HOSPITAL','HOSPITAL':'SUPERVISED CARE/HOSPITAL','HOTEL':"HOTEL",'OTHER':"OTHER",'RESIDENCE':"RESIDENCE",'SUPERVISED':"SUPERVISED CARE/HOSPITAL",'VEHICLE':"VEHICLE"}
add_df['cleaned_location'] = add_df['cleaned_location'].map(place)

#Fill the new location field with the original Location field where there are NAs
add_df.cleaned_location = add_df.cleaned_location.fillna('OTHER')

print(add_df.groupby(['cleaned_location'])['cleaned_location'].count())
print(add_df.groupby(['Location'])['Location'].count())
# Out:
# cleaned_location
# COMMERCIAL                    17
# HOTEL                        124
# OTHER                        364
# RESIDENCE                   2913
# SUPERVISED CARE/HOSPITAL    1638
# VEHICLE                       32
# Name: cleaned_location, dtype: int64
# Location
# CONVALESCENT HOME       3
# HOSPICE                 1
# HOSPITAL             1620
# NURSING HOME            1
# OTHER                 770
# RESIDENCE            2673
# Name: Location, dtype: int64

# %% [markdown]
# ## Which drug or combinations of drugs were most lethal?

# %% [markdown]
# Although the COD column explains the use of drugs, it is too verbose and is difficult to group similar values. We will create a new column 'drugs_involved' and poupulate it with the drugs marked 'Y' (suggesting involvement) separated by commas. We also have to arrange these in an alphabetical manner so it will make it easy to group them.

# %%
add_df
# Out:
#                         Date   new_date  Year Month day_of_week  \
# 0     01/01/2012 12:00:00 AM 2012-01-01  2012   JAN         SUN
# 1     01/03/2012 12:00:00 AM 2012-01-03  2012   JAN         TUE
# 2     01/04/2012 12:00:00 AM 2012-01-04  2012   JAN         WED
# 3     01/05/2012 12:00:00 AM 2012-01-05  2012   JAN        THUR
# 4     01/07/2012 12:00:00 AM 2012-01-07  2012   JAN         SAT
# 5     01/08/2012 12:00:00 AM 2012-01-08  2012   JAN         SUN
# 6     01/08/2012 12:00:00 AM 2012-01-08  2012   JAN         SUN
# 7     01/08/2012 12:00:00 AM 2012-01-08  2012   JAN         SUN
# 8     01/11/2012 12:00:00 AM 2012-01-11  2012   JAN         WED
# 9     01/12/2012 12:00:00 AM 2012-01-12  2012   JAN        THUR
# 10    01/12/2012 12:00:00 AM 2012-01-12  2012   JAN        THUR
# 11    01/13/2012 12:00:00 AM 2012-01-13  2012   JAN         FRI
# 12    01/14/2012 12:00:00 AM 2012-01-14  2012   JAN         SAT
# 13    01/14/2012 12:00:00 AM 2012-01-14  2012   JAN         SAT
# 14    01/15/2012 12:00:00 AM 2012-01-15  2012   JAN         SUN
# 15    01/16/2012 12:00:00 AM 2012-01-16  2012   JAN         MON
# 16    01/18/2012 12:00:00 AM 2012-01-18  2012   JAN         WED
# 17    01/20/2012 12:00:00 AM 2012-01-20  2012   JAN         FRI
# 18    01/22/2012 12:00:00 AM 2012-01-22  2012   JAN         SUN
# 19    01/23/2012 12:00:00 AM 2012-01-23  2012   JAN         MON
# 20    01/26/2012 12:00:00 AM 2012-01-26  2012   JAN        THUR
# 21    01/26/2012 12:00:00 AM 2012-01-26  2012   JAN        THUR
# 22    01/27/2012 12:00:00 AM 2012-01-27  2012   JAN         FRI
# 23    01/28/2012 12:00:00 AM 2012-01-28  2012   JAN         SAT
# 24    01/28/2012 12:00:00 AM 2012-01-28  2012   JAN         SAT
# 25    01/29/2012 12:00:00 AM 2012-01-29  2012   JAN         SUN
# 26    01/30/2012 12:00:00 AM 2012-01-30  2012   JAN         MON
# 27    01/30/2012 12:00:00 AM 2012-01-30  2012   JAN         MON
# 28    01/31/2012 12:00:00 AM 2012-01-31  2012   JAN         TUE
# 29    01/31/2012 12:00:00 AM 2012-01-31  2012   JAN         TUE
# ...                      ...        ...   ...   ...         ...
# 5058  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5059  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5060  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5061  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5062  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5063  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5064  12/17/2018 12:00:00 AM 2018-12-17  2018   DEC         MON
# 5065  12/19/2018 12:00:00 AM 2018-12-19  2018   DEC         WED
# 5066  12/20/2018 12:00:00 AM 2018-12-20  2018   DEC        THUR
# 5067  12/21/2018 12:00:00 AM 2018-12-21  2018   DEC         FRI
# 5068  12/22/2018 12:00:00 AM 2018-12-22  2018   DEC         SAT
# 5069  12/21/2018 12:00:00 AM 2018-12-21  2018   DEC         FRI
# 5070  12/23/2018 12:00:00 AM 2018-12-23  2018   DEC         SUN
# 5071  12/23/2018 12:00:00 AM 2018-12-23  2018   DEC         SUN
# 5072  12/24/2018 12:00:00 AM 2018-12-24  2018   DEC         MON
# 5073  12/24/2018 12:00:00 AM 2018-12-24  2018   DEC         MON
# 5074  12/25/2018 12:00:00 AM 2018-12-25  2018   DEC         TUE
# 5075  12/25/2018 12:00:00 AM 2018-12-25  2018   DEC         TUE
# 5076  12/26/2018 12:00:00 AM 2018-12-26  2018   DEC         WED
# 5077  12/27/2018 12:00:00 AM 2018-12-27  2018   DEC        THUR
# 5078  12/28/2018 12:00:00 AM 2018-12-28  2018   DEC         FRI
# 5079  12/28/2018 12:00:00 AM 2018-12-28  2018   DEC         FRI
# 5080  12/28/2018 12:00:00 AM 2018-12-28  2018   DEC         FRI
# 5081  12/28/2018 12:00:00 AM 2018-12-28  2018   DEC         FRI
# 5082  12/29/2018 12:00:00 AM 2018-12-29  2018   DEC         SAT
# 5083  12/29/2018 12:00:00 AM 2018-12-29  2018   DEC         SAT
# 5084  12/29/2018 12:00:00 AM 2018-12-29  2018   DEC         SAT
# 5085  12/29/2018 12:00:00 AM 2018-12-29  2018   DEC         SAT
# 5086  12/30/2018 12:00:00 AM 2018-12-30  2018   DEC         SUN
# 5087  12/31/2018 12:00:00 AM 2018-12-31  2018   DEC         MON
#
#                          Holiday   Age     Sex             Race  \
# 0                            NaN  35.0    MALE            WHITE
# 1                            NaN  41.0    MALE            WHITE
# 2                            NaN  61.0    MALE            BLACK
# 3                            NaN  51.0    MALE            WHITE
# 4                            NaN  45.0    MALE            WHITE
# 5                            NaN  51.0    MALE            WHITE
# 6                            NaN  24.0  FEMALE            WHITE
# 7                            NaN  33.0    MALE            WHITE
# 8                            NaN  54.0    MALE            WHITE
# 9                            NaN  46.0    MALE            WHITE
# 10                           NaN  32.0    MALE            WHITE
# 11                           NaN  53.0  FEMALE            WHITE
# 12                           NaN  18.0    MALE            WHITE
# 13                           NaN  23.0    MALE            WHITE
# 14                           NaN  38.0    MALE            WHITE
# 15    MARTIN LUTHER KING JR. DAY  35.0    MALE            WHITE
# 16                           NaN  63.0    MALE            WHITE
# 17                           NaN  33.0    MALE            WHITE
# 18                           NaN  44.0  FEMALE            WHITE
# 19                           NaN  31.0  FEMALE            WHITE
# 20                           NaN  35.0    MALE            WHITE
# 21                           NaN  20.0    MALE            WHITE
# 22                           NaN  40.0  FEMALE            WHITE
# 23                           NaN  43.0    MALE            BLACK
# 24                           NaN  46.0    MALE            WHITE
# 25                           NaN  35.0    MALE            WHITE
# 26                           NaN  50.0    MALE            WHITE
# 27                           NaN  45.0    MALE            WHITE
# 28                           NaN  28.0  FEMALE            WHITE
# 29                           NaN  56.0    MALE            WHITE
# ...                          ...   ...     ...              ...
# 5058                         NaN  51.0    MALE            WHITE
# 5059                         NaN  28.0    MALE            WHITE
# 5060                         NaN  50.0    MALE            WHITE
# 5061                         NaN  51.0    MALE            WHITE
# 5062                         NaN  25.0    MALE            WHITE
# 5063                         NaN  34.0    MALE            WHITE
# 5064                         NaN  54.0    MALE            WHITE
# 5065                         NaN  34.0    MALE            WHITE
# 5066                         NaN  27.0  FEMALE            WHITE
# 5067                         NaN  43.0    MALE            WHITE
# 5068                         NaN  47.0  FEMALE            WHITE
# 5069                         NaN  53.0    MALE            WHITE
# 5070                         NaN  52.0    MALE            WHITE
# 5071                         NaN  49.0    MALE            WHITE
# 5072                         NaN  22.0  FEMALE  HISPANIC, WHITE
# 5073                         NaN  37.0    MALE            WHITE
# 5074               CHRISTMAS DAY  54.0  FEMALE            BLACK
# 5075               CHRISTMAS DAY  27.0    MALE            WHITE
# 5076                         NaN  28.0    MALE  HISPANIC, WHITE
# 5077                         NaN  33.0    MALE            WHITE
# 5078                         NaN  24.0    MALE            WHITE
# 5079                         NaN  28.0    MALE            WHITE
# 5080                         NaN  41.0    MALE  HISPANIC, WHITE
# 5081                         NaN  33.0    MALE            WHITE
# 5082                         NaN  44.0  FEMALE            WHITE
# 5083                         NaN  46.0    MALE            WHITE
# 5084                         NaN  55.0    MALE            WHITE
# 5085                         NaN  58.0    MALE            WHITE
# 5086                         NaN  51.0  FEMALE            BLACK
# 5087                         NaN  57.0    MALE            WHITE
#
#          ResidenceCity            ...            Hydromorphone        Other  \
# 0               HEBRON            ...                      NaN          NaN
# 1              BRISTOL            ...                      NaN          NaN
# 2              DANBURY            ...                      NaN          NaN
# 3            STRATFORD            ...                      NaN          NaN
# 4             HARTFORD            ...                      NaN          NaN
# 5            WATERBURY            ...                      NaN          NaN
# 6             STAMFORD            ...                      NaN          NaN
# 7             BROOKLYN            ...                      NaN          NaN
# 8           DEEP RIVER            ...                      NaN          NaN
# 9          SOUTHINGTON            ...                      NaN    BATH SALT
# 10          PLAINFIELD            ...                      NaN          NaN
# 11            SIMSBURY            ...                      NaN          NaN
# 12          NEW LONDON            ...                      NaN          NaN
# 13             NORWICH            ...                      NaN          NaN
# 14         NEW BRITAIN            ...                      NaN          NaN
# 15           NAUGATUCK            ...                      NaN          NaN
# 16             NORWALK            ...                      NaN          NaN
# 17            COVENTRY            ...                      NaN          NaN
# 18              BETHEL            ...                      NaN          NaN
# 19            COVENTRY            ...                      NaN      OPIATES
# 20    NORTH STONINGTON            ...                      NaN          NaN
# 21              WILTON            ...                      NaN       OPIATE
# 22          MANCHESTER            ...                      NaN          NaN
# 23            HARTFORD            ...                      NaN          NaN
# 24              GROTON            ...                      NaN          NaN
# 25          EAST HAVEN            ...                      NaN          NaN
# 26           NEWINGTON            ...                      NaN          NaN
# 27        WETHERSFIELD            ...                      NaN          NaN
# 28       WEST HARTFORD            ...                      NaN          NaN
# 29              HAMDEN            ...                      NaN          NaN
# ...                ...            ...                      ...          ...
# 5058            BETHEL            ...                      NaN          NaN
# 5059         WATERBURY            ...                      NaN          NaN
# 5060           ENFIELD            ...                      NaN          NaN
# 5061            GOSHEN            ...                      NaN          NaN
# 5062        PLAINFIELD            ...                      NaN          NaN
# 5063           NORWICH            ...                      NaN          NaN
# 5064        NEW LONDON            ...                      NaN          NaN
# 5065     WINDSOR LOCKS            ...                      NaN          NaN
# 5066         STRATFORD            ...                      NaN          NaN
# 5067         SOUTHBURY            ...                      NaN          NaN
# 5068          HARTFORD            ...                      NaN       BUPREN
# 5069       NEW BRITAIN            ...                      NaN          NaN
# 5070          GUILFORD            ...                      NaN          NaN
# 5071         WATERTOWN            ...                      NaN          NaN
# 5072          GRISWOLD            ...                      NaN          NaN
# 5073           NIANTIC            ...                      NaN          NaN
# 5074         NEW HAVEN            ...                      NaN          NaN
# 5075            DARIEN            ...                      NaN          NaN
# 5076     EAST HARTFORD            ...                      NaN          NaN
# 5077        NEW LONDON            ...                      NaN          NaN
# 5078         SOUTHWICK            ...                      NaN  MITRAGYNINE
# 5079       NEW MILFORD            ...                      NaN          NaN
# 5080           REDDING            ...                      NaN          NaN
# 5081         WATERBURY            ...                      NaN          NaN
# 5082       WILLIMANTIC            ...                      NaN          NaN
# 5083        BRIDGEPORT            ...                      NaN          NaN
# 5084        COLCHESTER            ...                      NaN          NaN
# 5085            ROSCOE            ...                      NaN          NaN
# 5086           WINDSOR            ...                      NaN          NaN
# 5087         NEW HAVEN            ...                      NaN          NaN
#
#      OpiateNOS AnyOpioid         DeathCoordinates DeathCityExtracted  \
# 0          NaN       NaN  (41.658069, -72.366324)             HEBRON
# 1          NaN       NaN  (41.673037, -72.945791)            BRISTOL
# 2          NaN       NaN  (41.393666, -73.451539)            DANBURY
# 3          NaN       NaN  (41.179195, -73.189476)         BRIDGEPORT
# 4          NaN       NaN  (41.765775, -72.673356)           HARTFORD
# 5          NaN       NaN  (41.554261, -73.043069)          WATERBURY
# 6          NaN       NaN  (41.051924, -73.539475)           STAMFORD
# 7          NaN       NaN  (41.914993, -71.911904)             PUTNAM
# 8          NaN       NaN  (41.385619, -72.435658)         DEEP RIVER
# 9          NaN       NaN  (41.600428, -72.878105)        SOUTHINGTON
# 10         NaN       NaN  (41.524304, -72.075821)            NORWICH
# 11         NaN       NaN   (41.72651, -72.824947)         FARMINGTON
# 12         NaN       NaN  (41.355167, -72.099561)         NEW LONDON
# 13         NaN       NaN  (41.524304, -72.075821)            NORWICH
# 14         NaN       NaN  (41.667528, -72.783437)        NEW BRITAIN
# 15         NaN       NaN  (41.529492, -73.127625)         MIDDLEBURY
# 16         NaN       NaN   (41.11805, -73.412906)            NORWALK
# 17         NaN       NaN  (41.774042, -72.309999)           COVENTRY
# 18         NaN       NaN  (41.371727, -73.407448)             BETHEL
# 19         NaN       NaN  (41.765775, -72.673356)           HARTFORD
# 20         NaN       NaN   (41.43775, -71.879919)   NORTH STONINGTON
# 21         NaN       NaN  (41.765775, -72.673356)           HARTFORD
# 22         NaN       NaN  (41.770668, -72.520868)         MANCHESTER
# 23         NaN       NaN  (41.765775, -72.673356)           HARTFORD
# 24         NaN       NaN  (41.355167, -72.099561)         NEW LONDON
# 25         NaN       NaN  (41.308252, -72.924161)          NEW HAVEN
# 26         NaN       NaN  (41.698002, -72.723843)          NEWINGTON
# 27         NaN       NaN  (41.712487, -72.663607)       WETHERSFIELD
# 28         NaN       NaN  (41.765775, -72.673356)           HARTFORD
# 29         NaN       NaN  (41.382918, -72.907743)             HAMDEN
# ...        ...       ...                      ...                ...
# 5058       NaN         Y  (41.371727, -73.407448)             BETHEL
# 5059       NaN         Y  (41.554261, -73.043069)          WATERBURY
# 5060       NaN         Y  (41.953931, -72.302901)   STAFFORD SPRINGS
# 5061       NaN         Y  (41.831925, -73.225323)             GOSHEN
# 5062       NaN         Y   (41.67731, -71.918131)         PLAINFIELD
# 5063       NaN         Y  (41.524304, -72.075821)            NORWICH
# 5064       NaN         Y  (41.355167, -72.099561)         NEW LONDON
# 5065       NaN         Y  (41.924953, -72.627177)      WINDSOR LOCKS
# 5066       NaN         Y  (41.179195, -73.189476)         BRIDGEPORT
# 5067       NaN         Y  (41.466592, -73.203497)          SOUTHBURY
# 5068       NaN         Y  (41.765775, -72.673356)           HARTFORD
# 5069       NaN         Y  (41.554261, -73.043069)          WATERBURY
# 5070       NaN         Y  (41.281228, -72.681651)           GUILFORD
# 5071       NaN         Y   (41.606284, -73.11839)          WATERTOWN
# 5072       NaN         Y  (41.614599, -71.960584)           GRISWOLD
# 5073       NaN         Y   (41.32694, -72.193664)            NIANTIC
# 5074       NaN         Y  (41.308252, -72.924161)          NEW HAVEN
# 5075       NaN         Y  (41.051924, -73.539475)           STAMFORD
# 5076       NaN         Y  (41.765775, -72.673356)           HARTFORD
# 5077       NaN         Y  (41.355167, -72.099561)         NEW LONDON
# 5078       NaN         Y  (41.712487, -72.663607)       WETHERSFIELD
# 5079       NaN         Y  (41.576633, -73.408713)        NEW MILFORD
# 5080       NaN         Y  (41.382918, -72.907743)             HAMDEN
# 5081       NaN         Y  (41.554261, -73.043069)          WATERBURY
# 5082       NaN         Y  (41.711724, -72.211975)        WILLIMANTIC
# 5083       NaN         Y  (41.554261, -73.043069)          WATERBURY
# 5084       NaN         Y  (41.632043, -72.461309)        MARLBOROUGH
# 5085       NaN       NaN    (41.537589, -72.8011)            MERIDEN
# 5086       NaN         Y   (41.852781, -72.64379)            WINDSOR
# 5087       NaN         Y  (41.308252, -72.924161)          NEW HAVEN
#
#      ResidenceCityExtracted     ResidenceCoordinates Population  \
# 0                  HEBRON\r  (43.694742, -71.808963)     9686.0
# 1                 BRISTOL\r  (41.673037, -72.945791)    60477.0
# 2                 DANBURY\r  (41.393666, -73.451539)    80893.0
# 3               STRATFORD\r  (41.200888, -73.131323)   144229.0
# 4                HARTFORD\r  (41.765775, -72.673356)   124775.0
# 5               WATERBURY\r  (41.554261, -73.043069)   110366.0
# 6                STAMFORD\r  (41.051924, -73.539475)   122643.0
# 7                BROOKLYN\r  (40.692529, -73.990996)     7214.0
# 8              DEEP RIVER\r  (41.385619, -72.435658)     4629.0
# 9             SOUTHINGTON\r  (41.600428, -72.878105)    43069.0
# 10             PLAINFIELD\r   (41.608547, -88.20075)    40493.0
# 11               SIMSBURY\r  (41.875874, -72.801404)    25340.0
# 12             NEW LONDON\r  (41.355167, -72.099561)    27620.0
# 13                NORWICH\r  (41.524304, -72.075821)    40493.0
# 14            NEW BRITAIN\r  (41.667528, -72.783437)    73206.0
# 15              NAUGATUCK\r  (41.491113, -73.056564)     7575.0
# 16                NORWALK\r   (41.11805, -73.412906)    85603.0
# 17               COVENTRY\r  (41.701974, -71.593125)    12435.0
# 18                 BETHEL\r  (60.78492, -161.764266)    18584.0
# 19               COVENTRY\r  (41.701974, -71.593125)   124775.0
# 20       NORTH STONINGTON\r   (41.43775, -71.879919)     5297.0
# 21                 WILTON\r   (41.19444, -73.432397)   124775.0
# 22             MANCHESTER\r  (42.990926, -71.463091)    30577.0
# 23               HARTFORD\r  (41.765775, -72.673356)   124775.0
# 24                 GROTON\r   (41.343693, -72.07877)    27620.0
# 25             EAST HAVEN\r  (41.277971, -72.871954)   129779.0
# 26              NEWINGTON\r  (41.698002, -72.723843)    30562.0
# 27           WETHERSFIELD\r  (41.712487, -72.663607)    26668.0
# 28          WEST HARTFORD\r  (41.762008, -72.741807)   124775.0
# 29                 HAMDEN\r  (41.382918, -72.907743)    60960.0
# ...                     ...                      ...        ...
# 5058           BETHEL, CT\r  (41.371727, -73.407448)    18584.0
# 5059        WATERBURY, CT\r  (41.554261, -73.043069)   110366.0
# 5060          ENFIELD, CT\r  (41.976501, -72.591985)     4988.0
# 5061           GOSHEN, CT\r  (41.831925, -73.225323)     2976.0
# 5062       PLAINFIELD, CT\r   (41.67731, -71.918131)    15405.0
# 5063          NORWICH, CT\r  (41.524304, -72.075821)    40493.0
# 5064       NEW LONDON, CT\r  (41.355167, -72.099561)    27620.0
# 5065    WINDSOR LOCKS, CT\r  (41.924953, -72.627177)    12498.0
# 5066        STRATFORD, CT\r  (41.200888, -73.131323)   144229.0
# 5067        SOUTHBURY, CT\r  (41.466592, -73.203497)    19904.0
# 5068         HARTFORD, CT\r  (41.765775, -72.673356)   124775.0
# 5069      NEW BRITAIN, CT\r  (41.667528, -72.783437)   110366.0
# 5070         GUILFORD, CT\r  (41.281228, -72.681651)    22375.0
# 5071        WATERTOWN, CT\r   (41.606284, -73.11839)     3574.0
# 5072         GRISWOLD, CT\r  (41.614599, -71.960584)    11951.0
# 5073          NIANTIC, CT\r   (41.32694, -72.193664)     3114.0
# 5074        NEW HAVEN, CT\r  (41.308252, -72.924161)   129779.0
# 5075           DARIEN, CT\r  (41.080002, -73.467371)   122643.0
# 5076    EAST HARTFORD, CT\r  (41.769319, -72.643785)   124775.0
# 5077       NEW LONDON, CT\r  (41.355167, -72.099561)    27620.0
# 5078        SOUTHWICK, MA\r  (42.054808, -72.770113)    26668.0
# 5079      NEW MILFORD, CT\r  (41.576633, -73.408713)     6523.0
# 5080          REDDING, PA\r  (40.336919, -75.921965)    60960.0
# 5081        WATERBURY, CT\r  (41.554261, -73.043069)   110366.0
# 5082      WILLIMANTIC, CT\r  (41.711724, -72.211975)    17737.0
# 5083       BRIDGEPORT, CT\r  (41.179195, -73.189476)   110366.0
# 5084       COLCHESTER, CT\r   (41.57348, -72.332129)     6404.0
# 5085           ROSCOE, NY\r   (41.94425, -74.913273)    60868.0
# 5086          WINDSOR, CT\r   (41.852781, -72.64379)    29044.0
# 5087        NEW HAVEN, CT\r  (41.308252, -72.924161)   129779.0
#
#               cleaned_location
# 0                    RESIDENCE
# 1     SUPERVISED CARE/HOSPITAL
# 2     SUPERVISED CARE/HOSPITAL
# 3                    RESIDENCE
# 4                    RESIDENCE
# 5                    RESIDENCE
# 6     SUPERVISED CARE/HOSPITAL
# 7     SUPERVISED CARE/HOSPITAL
# 8                    RESIDENCE
# 9     SUPERVISED CARE/HOSPITAL
# 10    SUPERVISED CARE/HOSPITAL
# 11    SUPERVISED CARE/HOSPITAL
# 12    SUPERVISED CARE/HOSPITAL
# 13                   RESIDENCE
# 14                   RESIDENCE
# 15                   RESIDENCE
# 16                   RESIDENCE
# 17                   RESIDENCE
# 18                   RESIDENCE
# 19    SUPERVISED CARE/HOSPITAL
# 20                   RESIDENCE
# 21    SUPERVISED CARE/HOSPITAL
# 22                     VEHICLE
# 23    SUPERVISED CARE/HOSPITAL
# 24    SUPERVISED CARE/HOSPITAL
# 25    SUPERVISED CARE/HOSPITAL
# 26                   RESIDENCE
# 27                   RESIDENCE
# 28    SUPERVISED CARE/HOSPITAL
# 29                   RESIDENCE
# ...                        ...
# 5058                 RESIDENCE
# 5059                 RESIDENCE
# 5060  SUPERVISED CARE/HOSPITAL
# 5061                 RESIDENCE
# 5062                 RESIDENCE
# 5063                 RESIDENCE
# 5064  SUPERVISED CARE/HOSPITAL
# 5065                     OTHER
# 5066  SUPERVISED CARE/HOSPITAL
# 5067                 RESIDENCE
# 5068                 RESIDENCE
# 5069                     OTHER
# 5070                 RESIDENCE
# 5071                 RESIDENCE
# 5072                 RESIDENCE
# 5073                     OTHER
# 5074                     OTHER
# 5075  SUPERVISED CARE/HOSPITAL
# 5076  SUPERVISED CARE/HOSPITAL
# 5077  SUPERVISED CARE/HOSPITAL
# 5078                     OTHER
# 5079                 RESIDENCE
# 5080                     OTHER
# 5081  SUPERVISED CARE/HOSPITAL
# 5082                 RESIDENCE
# 5083  SUPERVISED CARE/HOSPITAL
# 5084  SUPERVISED CARE/HOSPITAL
# 5085                     OTHER
# 5086                 RESIDENCE
# 5087                 RESIDENCE
#
# [5088 rows x 38 columns]

# %%
#Get Column names
add_df.columns
# Out:
# Index(['Date', 'new_date', 'Year', 'Month', 'day_of_week', 'Holiday', 'Age',
#        'Sex', 'Race', 'ResidenceCity', 'ResidenceState_update', 'DeathCity',
#        'Location', 'LocationifOther', 'DescriptionofInjury', 'Heroin',
#        'Cocaine', 'Fentanyl', 'FentanylAnalogue', 'Oxycodone', 'Oxymorphone',
#        'Ethanol', 'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet',
#        'Tramad', 'Morphine_NotHeroin', 'Hydromorphone', 'Other', 'OpiateNOS',
#        'AnyOpioid', 'DeathCoordinates', 'DeathCityExtracted',
#        'ResidenceCityExtracted', 'ResidenceCoordinates', 'Population',
#        'cleaned_location'],
#       dtype='object')

# %%
#Replace the indicator 'Y' with the name of the column in uppercase (in this case, the name of the drug).
#If null, don't change the value
def assignDrugName(value, column):
    if(value == 'Y'):
        return str(column).upper()
    else:
        return value

# Loop through the drugs columns. Don't change anything in the 'Other' column since it already has the name.
for column in add_df.loc[:, 'Heroin':'AnyOpioid']:
    if(column != 'Other'):
        add_df[column] = add_df[column].map(lambda value: assignDrugName(value, column))

add_df.loc[:, 'Heroin':'AnyOpioid'].head()

add_df.AnyOpioid = add_df.AnyOpioid.fillna('N')

# %%
#Create a new column and append the values in the drug columns to track multiple-use
add_df['drugs_used'] = add_df.loc[:, 'Heroin':'AnyOpioid'].apply(lambda value: ', '.join(value[value.notnull()]), axis = 1)
add_df['drugs_used'].value_counts()
# Out:
# HEROIN, N                                                                         340
# COCAINE, N                                                                        217
# HEROIN, ANYOPIOID                                                                 209
# FENTANYL, ANYOPIOID                                                               200
# HEROIN, FENTANYL, ANYOPIOID                                                       162
# HEROIN, COCAINE, N                                                                144
# FENTANYL, N                                                                       106
# HEROIN, FENTANYL, N                                                               101
# COCAINE, FENTANYL, ANYOPIOID                                                       99
# HEROIN, ETHANOL, N                                                                 96
# HEROIN, COCAINE, ANYOPIOID                                                         86
# HEROIN, COCAINE, FENTANYL, ANYOPIOID                                               82
# HEROIN, FENTANYL, ETHANOL, ANYOPIOID                                               74
# FENTANYL, ETHANOL, ANYOPIOID                                                       72
# HEROIN, ETHANOL, ANYOPIOID                                                         69
# ETHANOL, BENZODIAZEPINE, N                                                         63
# HEROIN, BENZODIAZEPINE, ANYOPIOID                                                  57
# HEROIN, FENTANYL, BENZODIAZEPINE, ANYOPIOID                                        56
# HEROIN, BENZODIAZEPINE, N                                                          54
# COCAINE, FENTANYL, N                                                               54
# METHADONE, N                                                                       53
# OXYCODONE, N                                                                       52
# HEROIN, COCAINE, FENTANYL, N                                                       48
# FENTANYL, BENZODIAZEPINE, ANYOPIOID                                                46
# HEROIN, COCAINE, ETHANOL, N                                                        44
# FENTANYL, ETHANOL, N                                                               42
# FENTANYL, BENZODIAZEPINE, N                                                        42
# BENZODIAZEPINE, METHADONE, ANYOPIOID                                               41
# COCAINE, ETHANOL, N                                                                40
# FENTANYL, FENTANYLANALOGUE, ANYOPIOID                                              37
#                                                                                  ...
# FENTANYL, AMPHET, BUPREN, ANYOPIOID                                                 1
# HEROIN, COCAINE, FENTANYL, BENZODIAZEPINE, TRAMAD, N                                1
# HEROIN, FENTANYL, MEPERIDINE, ANYOPIOID                                             1
# FENTANYL, ETHANOL, BENZODIAZEPINE, METHADONE, ANYOPIOID                             1
# OXYCODONE, HYDROMORPHONE, ANYOPIOID                                                 1
# HEROIN, FENTANYL, BUPREN, ANYOPIOID                                                 1
# ETHANOL, BUPREN, ANYOPIOID                                                          1
# BENZODIAZEPINE, CODEINE, ANYOPIOID                                                  1
# COCAINE, OTHERS, N                                                                  1
# OXYCODONE, HYDROCODONE, ANYOPIOID                                                   1
# FENTANYL, FENTANYLANALOGUE, METHADONE, ANYOPIOID                                    1
# HEROIN, OXYCODONE, METHADONE, ANYOPIOID                                             1
# OXYCODONE, HYDROCODONE, H-MORPH, N                                                  1
# FENTANYL, BUPREN, ANYOPIOID                                                         1
# COCAINE, FENTANYL, FENTANYLANALOGUE, ETHANOL, BENZODIAZEPINE, METHADONE, N          1
# ETHANOL, BENZODIAZEPINE, MORPHINE, N                                                1
# HEROIN, COCAINE, FENTANYL, OXYCODONE, METHADONE, ANYOPIOID                          1
# HEROIN, BENZODIAZEPINE, METHADONE, HYDROMORPHONE, N                                 1
# HEROIN, OXYCODONE, ETHANOL, BENZODIAZEPINE, N                                       1
# OXYCODONE, OTHERS, N                                                                1
# HEROIN, FENTANYL, ETHANOL, BUPREN, ANYOPIOID                                        1
# OXYCODONE, HYDROCODONE, BENZODIAZEPINE, TRAMAD, ANYOPIOID                           1
# COCAINE, MORPHINE_NOTHEROIN, ANYOPIOID                                              1
# HEROIN, FENTANYL, TRAMAD, PCP, ANYOPIOID                                            1
# ETHANOL, METHADONE, BUPREN, ANYOPIOID                                               1
# COCAINE, FENTANYL, BENZODIAZEPINE, AMPHET, BUPREN, ANYOPIOID                        1
# OXYCODONE, HYDROCODONE, METHADONE, N                                                1
# HEROIN, COCAINE, FENTANYL, FENTANYLANALOGUE, BENZODIAZEPINE, TRAMAD, ANYOPIOID      1
# HEROIN, OXYCODONE, OXYMORPHONE, BENZODIAZEPINE, N                                   1
# COCAINE, BENZODIAZEPINE, METHADONE, TRAMAD, ANYOPIOID                               1
# Name: drugs_used, Length: 821, dtype: int64

# %%
drugs_used_counts = add_df['drugs_used'].value_counts()
drugs_used_counts = drugs_used_counts.loc[drugs_used_counts > 100]
drugs_used_counts.plot(kind='barh', figsize=(10,7), color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'], fontsize=13);
plt.show()

# %%
drugs_used_counts.loc[drugs_used_counts > 100]
# Out:
# HEROIN, N                      340
# COCAINE, N                     217
# HEROIN, ANYOPIOID              209
# FENTANYL, ANYOPIOID            200
# HEROIN, FENTANYL, ANYOPIOID    162
# HEROIN, COCAINE, N             144
# FENTANYL, N                    106
# HEROIN, FENTANYL, N            101
# Name: drugs_used, dtype: int64

# %% [markdown]
# # Age as an explanatory variable?

# %% [markdown]
# We will group 'Age' into bins of range 5 to create a population pyramid to get a better understanding of the demographic.

# %%
#Age graph grouped into a population pyramid for an overview
bins = pd.cut(add_df['Age'], [0, 29, 39, 49,59, 69, 70], labels = ['0 - 29', '30 - 39', '40 - 49', '50 - 59', '60 - 69', '70+'])
add_df_Age = add_df.groupby(bins)['Age'].agg('count')
add_df_Age.plot(kind='bar', figsize = (10,7), fontsize=13, color = ['darksalmon', 'coral', 'orange', 'gold', 'darkorange', 'lightsalmon']);
plt.show()
add_df_Age.sort_values(ascending = False)
# Out:
# Age
# 30 - 39    1262
# 40 - 49    1229
# 50 - 59    1202
# 0 - 29     1006
# 60 - 69     351
# 70+           7
# Name: Age, dtype: int64

# %%
# Count differences in Sex

add_df.groupby('Sex')['Age'].count()
# Out:
# Sex
# FEMALE    1320
# MALE      3767
# Name: Age, dtype: int64

# %%
# Count differences in Sex by percentage

def percentage (part, whole):
    return 100 * float(part)/float(whole)

percentfemale = percentage (1320, 5087)
percentmale = percentage (3767, 5087)

print('% of Male:', percentmale, '% of Female:', percentfemale)
# Out:
# % of Male: 74.05150383330057 % of Female: 25.94849616669943

# %%
# Locating subject with Sex not defined

SexUnknownloc = np.where(add_df['Sex'] == 'UNKNOWN')
SexUnknownloc
# Out:
# (array([], dtype=int64),)

# %%
# Dropping subject with Sex not defined

add_df.drop(add_df.index[4122], inplace=True)

# %%
# Pivot Table, grouped by Sex and Age 

bins = pd.cut(add_df['Age'], [0, 29, 39, 49, 59, 69, 70], labels = ['0 - 29', '30 - 39', '40 - 49', '50 - 59', '60 - 69', '70+'])
sex_age = add_df.pivot_table('Age', index = bins, columns = 'Sex', aggfunc='count')
sex_age
# Out:
# Sex      FEMALE  MALE
# Age
# 0 - 29      269   737
# 30 - 39     272   989
# 40 - 49     334   895
# 50 - 59     347   855
# 60 - 69      84   267
# 70+           2     5

# %%
# Plotting age group counts for Male & Female

sex_age.plot(kind='bar', figsize = (10,7), fontsize=13, color = ['orange', 'gold'])

# %%
# Changes in Age of Male & Female over time

yrsex = add_df.pivot_table('Age', index = 'Year', columns = 'Sex', aggfunc = 'mean');
yrsex
# Out:
# Sex      FEMALE       MALE
# Year
# 2012  42.020619  40.302326
# 2013  42.871429  40.794286
# 2014  41.993976  41.419023
# 2015  44.136842  41.652985
# 2016  41.730435  42.140556
# 2017  42.329457  41.517375
# 2018  42.584034  42.799742

# %%
# Plotting the changes in Age of Male & Female over time

yrsex.plot(kind='line', figsize = (10,7), fontsize = 13, color = ['orange', 'gold'])

# %%
# Changes in Male & Female count over time

yrsex2 = add_df.groupby(['Year', 'Sex'])['Sex'].count();
yrsex2
# Out:
# Year  Sex
# 2012  FEMALE     97
#       MALE      258
# 2013  FEMALE    140
#       MALE      350
# 2014  FEMALE    166
#       MALE      389
# 2015  FEMALE    190
#       MALE      536
# 2016  FEMALE    230
#       MALE      683
# 2017  FEMALE    258
#       MALE      777
# 2018  FEMALE    238
#       MALE      774
# Name: Sex, dtype: int64

# %%
# Plotting the changes in Male & Female count over time

add_df.groupby(['Year', 'Sex'])['Sex'].count().unstack().plot(figsize = (10, 7), fontsize = 13, color = ['orange', 'gold'])

# %% [markdown]
# # Location as an explanatory variable?

# %%
#Count of the locations that individuals died at
location_counts = add_df['cleaned_location'].value_counts()
location_counts.plot(kind='barh', figsize=(10,7), color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'], fontsize=13);
plt.show()

# %%
print(add_df.groupby(['cleaned_location','Sex'])['Age'].mean())
# Out:
# cleaned_location          Sex
# COMMERCIAL                FEMALE    28.000000
#                           MALE      39.812500
# HOTEL                     FEMALE    41.000000
#                           MALE      42.872549
# OTHER                     FEMALE    40.467532
#                           MALE      39.895470
# RESIDENCE                 FEMALE    43.850727
#                           MALE      42.322970
# SUPERVISED CARE/HOSPITAL  FEMALE    40.753813
#                           MALE      41.101781
# VEHICLE                   FEMALE    43.750000
#                           MALE      41.321429
# Name: Age, dtype: float64

# %%
#examination of age vs location
location_age = add_df.pivot_table('Age', index = bins, columns = 'cleaned_location', aggfunc='count',dropna=True,fill_value=0)
#location_age
print(location_age)

location_age_pct = pd.crosstab(bins,add_df['cleaned_location']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# cleaned_location  COMMERCIAL  HOTEL  OTHER  RESIDENCE  \
# Age
# (30, 40]                   0      1      7         47
# (40, 50]                   6     23     86        554
# (60, 70]                   5     30    106        703
# (50, 60]                   0     36     87        706
# (20, 30]                   6     25     66        693
# (10, 20]                   0      9      7        191
# (70, 80]                   0      0      5         17
# (80, 90]                   0      0      0          1
#
# cleaned_location  SUPERVISED CARE/HOSPITAL  VEHICLE
# Age
# (30, 40]                                36        0
# (40, 50]                               370        6
# (60, 70]                               392       10
# (50, 60]                               424        7
# (20, 30]                               336        8
# (10, 20]                                73        1
# (70, 80]                                 5        0
# (80, 90]                                 2        0

# %%
location_age_pct.plot(kind='barh', stacked=True, figsize = (17,7), fontsize=13, color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'])

# %%
age_location_pct = pd.crosstab(add_df['cleaned_location'],bins).apply(lambda r: r/r.sum(), axis=1)
age_location_pct.plot(kind='barh', stacked=True, figsize = (17,7), fontsize=13, color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'])

# %%
sex_location_pct = pd.crosstab(add_df['cleaned_location'],add_df.Sex).apply(lambda r: r/r.sum(), axis=1)
sex_location_pct.plot(kind='barh', stacked=True, figsize = (17,7), fontsize=13, color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'])

# %%
opioid_location_pct = pd.crosstab(add_df['cleaned_location'],add_df.AnyOpioid).apply(lambda r: r/r.sum(), axis=1)
opioid_location_pct.plot(kind='barh', stacked=True, figsize = (17,7), fontsize=13, color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'])

# %%
#Count of the locations that individuals died at
city_counts = add_df['DeathCityExtracted'].value_counts()
city_counts = city_counts.loc[city_counts > 100]

city_counts.plot(kind='barh', figsize=(10,7), color=['navy', 'blue', 'royalblue', 'deepskyblue', 'mediumblue', 'cornflowerblue', 'dodgerblue', 'slategray'], fontsize=13);
plt.show()

# %%
#deaths by city per capita
top_cities = add_df.groupby(['DeathCity'])['DeathCity'].count().sort_values(ascending=False)[:10]
print(top_cities)

df_top_cities = pd.DataFrame({'DeathCity':top_cities.index, 'Deaths':top_cities.values})

df_top_cities = pd.merge(df_top_cities,connecticut,left_on='DeathCity', right_on='Town', how='left')

df_top_cities.drop(['Town'],axis=1)

df_top_cities['PerCapita']=(df_top_cities['Deaths']/df_top_cities['Population'])*100
# Out:
# DeathCity
# HARTFORD       560
# NEW HAVEN      372
# WATERBURY      368
# BRIDGEPORT     340
# NEW BRITAIN    226
# MERIDEN        145
# BRISTOL        144
# NORWICH        144
# NEW LONDON     137
# DANBURY        131
# Name: DeathCity, dtype: int64

# %%
df_top_cities
# Out:
#      DeathCity  Deaths         Town  Population  PerCapita
# 0     HARTFORD     560     HARTFORD      124775   0.448808
# 1    NEW HAVEN     372    NEW HAVEN      129779   0.286641
# 2    WATERBURY     368    WATERBURY      110366   0.333436
# 3   BRIDGEPORT     340   BRIDGEPORT      144229   0.235736
# 4  NEW BRITAIN     226  NEW BRITAIN       73206   0.308718
# 5      MERIDEN     145      MERIDEN       60868   0.238220
# 6      BRISTOL     144      BRISTOL       60477   0.238107
# 7      NORWICH     144      NORWICH       40493   0.355617
# 8   NEW LONDON     137   NEW LONDON       27620   0.496017
# 9      DANBURY     131      DANBURY       80893   0.161942

# %% [markdown]
# # Cross Analysis
# Analyzing the relationship of age, race and sex

# %%
#Add age class column based on age values
def func(row):
    if row['Age'] < 30:
        return '0-29'
    elif row['Age'] >= 30 and row['Age'] < 40:
        return '30-39'
    elif row['Age'] >= 40 and row['Age'] < 50:
        return '40-49'
    elif row['Age'] >= 50 and row['Age'] < 60:
        return '50-59'
    elif row['Age'] >= 60 and row['Age'] < 70:
        return '60-69'
    elif row['Age'] >= 70:
        return '70+'

add_df['ageClass'] = add_df.apply(func, axis=1)

add_df.head()
# Out:
#                      Date   new_date  Year Month day_of_week Holiday   Age  \
# 0  01/01/2012 12:00:00 AM 2012-01-01  2012   JAN         SUN     NaN  35.0
# 1  01/03/2012 12:00:00 AM 2012-01-03  2012   JAN         TUE     NaN  41.0
# 2  01/04/2012 12:00:00 AM 2012-01-04  2012   JAN         WED     NaN  61.0
# 3  01/05/2012 12:00:00 AM 2012-01-05  2012   JAN        THUR     NaN  51.0
# 4  01/07/2012 12:00:00 AM 2012-01-07  2012   JAN         SAT     NaN  45.0
#
#     Sex   Race ResidenceCity  ... OpiateNOS AnyOpioid  \
# 0  MALE  WHITE        HEBRON  ...       NaN         N
# 1  MALE  WHITE       BRISTOL  ...       NaN         N
# 2  MALE  BLACK       DANBURY  ...       NaN         N
# 3  MALE  WHITE     STRATFORD  ...       NaN         N
# 4  MALE  WHITE      HARTFORD  ...       NaN         N
#
#           DeathCoordinates DeathCityExtracted ResidenceCityExtracted  \
# 0  (41.658069, -72.366324)             HEBRON                 HEBRON
# 1  (41.673037, -72.945791)            BRISTOL                BRISTOL
# 2  (41.393666, -73.451539)            DANBURY                DANBURY
# 3  (41.179195, -73.189476)         BRIDGEPORT              STRATFORD
# 4  (41.765775, -72.673356)           HARTFORD               HARTFORD
#
#       ResidenceCoordinates Population          cleaned_location  \
# 0  (43.694742, -71.808963)     9686.0                 RESIDENCE
# 1  (41.673037, -72.945791)    60477.0  SUPERVISED CARE/HOSPITAL
# 2  (41.393666, -73.451539)    80893.0  SUPERVISED CARE/HOSPITAL
# 3  (41.200888, -73.131323)   144229.0                 RESIDENCE
# 4  (41.765775, -72.673356)   124775.0                 RESIDENCE
#
#                   drugs_used ageClass
# 0         HEROIN, COCAINE, N    30-39
# 1  HEROIN, BENZODIAZEPINE, N    40-49
# 2                 COCAINE, N    60-69
# 3               METHADONE, N    50-59
# 4                  HEROIN, N    40-49
#
# [5 rows x 40 columns]

# %%
#Subsetting the dataframe for analysis and visualizations
addSub = add_df[['Age', 'ageClass', 'Race', 'Sex', 'Year']]
addSub.head()
# Out:
#     Age ageClass   Race   Sex  Year
# 0  35.0    30-39  WHITE  MALE  2012
# 1  41.0    40-49  WHITE  MALE  2012
# 2  61.0    60-69  BLACK  MALE  2012
# 3  51.0    50-59  WHITE  MALE  2012
# 4  45.0    40-49  WHITE  MALE  2012

# %% [markdown]
# ### Analyzing the three variables

# %%
#Explore the distribution of observations for each group in the race column
addSub.groupby('Sex')['Sex'].count()
# Out:
# Sex
# FEMALE     1320
# MALE       3767
# UNKNOWN       1
# Name: Sex, dtype: int64

# %%
#Explore the distribution of observations for each group in the race column
addSub.groupby('Race')['Race'].count()
# Out:
# Race
# ASIAN INDIAN                14
# ASIAN, OTHER                18
# BLACK                      433
# CHINESE                      2
# HAWAIIAN                     1
# HISPANIC, BLACK             24
# HISPANIC, WHITE            560
# NATIVE AMERICAN, OTHER       1
# OTHER                       11
# UNKNOWN                     23
# WHITE                     4001
# Name: Race, dtype: int64

# %% [markdown]
# Reviewing the groupby for sex and race indicate some groups have minimal records:
# * unknown from the sex column
# * all but black, hispanic/white, and white from the race column
#
# The dataframe is filtered to remove groups from the sex and race columns that do not have a significant number of records

# %%
#Remove all occurances of 'unknown' from the sex column
addSub = addSub[addSub.Sex != 'UNKNOWN']

# %%
#Remove all occurances other than 'black', 'hispanic, white', and 'white' from the race column
races = ['BLACK', 'HISPANIC, WHITE', 'WHITE']
addSub = addSub[addSub.Race.isin(races)]

# %% [markdown]
# ## Performing cross analysis between multiple columns

# %%
#Explore the distribution of observations for each group in the age class and sex column
addSub.groupby(['Sex', 'ageClass'])['Sex'].count()
# Out:
# Sex     ageClass
# FEMALE  0-29        261
#         30-39       269
#         40-49       329
#         50-59       343
#         60-69        84
#         70+          13
# MALE    0-29        715
#         30-39       970
#         40-49       882
#         50-59       841
#         60-69       263
#         70+          23
# Name: Sex, dtype: int64

# %%
#Explore the distribution of observations for each group in the age class and race column
addSub.groupby(['Race', 'ageClass'])['Race'].count()
# Out:
# Race             ageClass
# BLACK            0-29          49
#                  30-39         80
#                  40-49        107
#                  50-59        135
#                  60-69         57
#                  70+            5
# HISPANIC, WHITE  0-29          89
#                  30-39        129
#                  40-49        191
#                  50-59        118
#                  60-69         26
#                  70+            7
# WHITE            0-29         838
#                  30-39       1030
#                  40-49        913
#                  50-59        931
#                  60-69        264
#                  70+           24
# Name: Race, dtype: int64

# %%
#Explore the distribution of observations for each group in the sex and race column
addSub.groupby(['Sex', 'Race'])['Race'].count()
# Out:
# Sex     Race
# FEMALE  BLACK               112
#         HISPANIC, WHITE      98
#         WHITE              1089
# MALE    BLACK               321
#         HISPANIC, WHITE     462
#         WHITE              2911
# Name: Race, dtype: int64

# %%
#Explore the distribution of observations for each group in the age class, sex and race column
addSub.groupby(['Sex', 'Race', 'ageClass'])['Race'].count()
# Out:
# Sex     Race             ageClass
# FEMALE  BLACK            0-29         14
#                          30-39        16
#                          40-49        35
#                          50-59        34
#                          60-69        12
#                          70+           1
#         HISPANIC, WHITE  0-29         20
#                          30-39        24
#                          40-49        29
#                          50-59        20
#                          60-69         4
#                          70+           1
#         WHITE            0-29        227
#                          30-39       229
#                          40-49       265
#                          50-59       289
#                          60-69        68
#                          70+          11
# MALE    BLACK            0-29         35
#                          30-39        64
#                          40-49        72
#                          50-59       101
#                          60-69        45
#                          70+           4
#         HISPANIC, WHITE  0-29         69
#                          30-39       105
#                          40-49       162
#                          50-59        98
#                          60-69        22
#                          70+           6
#         WHITE            0-29        611
#                          30-39       801
#                          40-49       648
#                          50-59       642
#                          60-69       196
#                          70+          13
# Name: Race, dtype: int64

# %%
#Analyze the age statistics (min, mean, median, and max) for the race column
print("Minimum age by race")
print(addSub.groupby('Race')['Age'].min())  
print("")
print("Mean age by race")
print(addSub.groupby('Race')['Age'].mean())
print("")
print("Median age by race")
print(addSub.groupby('Race')['Age'].median())
print("")
print("Max age by race")
print(addSub.groupby('Race')['Age'].max())
# Out:
# Minimum age by race
# Race
# BLACK              19.0
# HISPANIC, WHITE    17.0
# WHITE              14.0
# Name: Age, dtype: float64
#
# Mean age by race
# Race
# BLACK              46.556582
# HISPANIC, WHITE    42.544643
# WHITE              41.446500
# Name: Age, dtype: float64
#
# Median age by race
# Race
# BLACK              48.0
# HISPANIC, WHITE    43.0
# WHITE              41.0
# Name: Age, dtype: float64
#
# Max age by race
# Race
# BLACK              75.0
# HISPANIC, WHITE    87.0
# WHITE              81.0
# Name: Age, dtype: float64

# %%
#Analyze the age statistics (min, mean, median, and max) for the sex column
print("Minimum age by sex")
print(addSub.groupby('Sex')['Age'].min())
print("")
print("Mean age by sex")
print(addSub.groupby('Sex')['Age'].mean())
print("")
print("Median age by sex")
print(addSub.groupby('Sex')['Age'].median())
print("")
print("Maximum age by sex")
print(addSub.groupby('Sex')['Age'].max())
# Out:
# Minimum age by sex
# Sex
# FEMALE    14.0
# MALE      15.0
# Name: Age, dtype: float64
#
# Mean age by sex
# Sex
# FEMALE    42.617398
# MALE      41.800217
# Name: Age, dtype: float64
#
# Median age by sex
# Sex
# FEMALE    44.0
# MALE      41.0
# Name: Age, dtype: float64
#
# Maximum age by sex
# Sex
# FEMALE    81.0
# MALE      87.0
# Name: Age, dtype: float64

# %%
#Analyze the age statistics (min, mean, median, and max) for the sex and sex column
print("Minimum age by sex and race")
print(addSub.groupby(['Sex', 'Race'])['Age'].min())
print("")
print("Mean age by sex and race")
print(addSub.groupby(['Sex', 'Race'])['Age'].mean())
print("")
print("Median age by sex and race")
print(addSub.groupby(['Sex', 'Race'])['Age'].median())
print("")
print("Maximum age by sex and race")
print(addSub.groupby(['Sex', 'Race'])['Age'].max())
# Out:
# Minimum age by sex and race
# Sex     Race
# FEMALE  BLACK              19.0
#         HISPANIC, WHITE    21.0
#         WHITE              14.0
# MALE    BLACK              20.0
#         HISPANIC, WHITE    17.0
#         WHITE              15.0
# Name: Age, dtype: float64
#
# Mean age by sex and race
# Sex     Race
# FEMALE  BLACK              46.142857
#         HISPANIC, WHITE    41.010204
#         WHITE              42.399449
# MALE    BLACK              46.700935
#         HISPANIC, WHITE    42.870130
#         WHITE              41.090003
# Name: Age, dtype: float64
#
# Median age by sex and race
# Sex     Race
# FEMALE  BLACK              48.0
#         HISPANIC, WHITE    43.5
#         WHITE              43.0
# MALE    BLACK              49.0
#         HISPANIC, WHITE    43.0
#         WHITE              40.0
# Name: Age, dtype: float64
#
# Maximum age by sex and race
# Sex     Race
# FEMALE  BLACK              70.0
#         HISPANIC, WHITE    72.0
#         WHITE              81.0
# MALE    BLACK              75.0
#         HISPANIC, WHITE    87.0
#         WHITE              75.0
# Name: Age, dtype: float64

# %%
#Count of deaths by year and race
yrRace = addSub.groupby(['Race','Year'])['Race'].count().reset_index(name="Count")
yrRace
# Out:
#                Race  Year  Count
# 0             BLACK  2012     38
# 1             BLACK  2013     44
# 2             BLACK  2014     27
# 3             BLACK  2015     46
# 4             BLACK  2016     86
# 5             BLACK  2017     88
# 6             BLACK  2018    104
# 7   HISPANIC, WHITE  2012     38
# 8   HISPANIC, WHITE  2013     52
# 9   HISPANIC, WHITE  2014     54
# 10  HISPANIC, WHITE  2015     76
# 11  HISPANIC, WHITE  2016     98
# 12  HISPANIC, WHITE  2017    113
# 13  HISPANIC, WHITE  2018    129
# 14            WHITE  2012    274
# 15            WHITE  2013    388
# 16            WHITE  2014    468
# 17            WHITE  2015    593
# 18            WHITE  2016    711
# 19            WHITE  2017    813
# 20            WHITE  2018    753

# %%
#Plot deaths by year (wanting to have groups by race)
yrRace.plot.line(x='Year', y='Count')
